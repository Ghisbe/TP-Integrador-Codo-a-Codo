# %% [markdown]
# # Consignas #6:
# ---
#
# ### CONSIGNA #6
# **A.** Usaremos la BBDD sqlite **<font color='red'>netflix_oscar.db</font>** que contiene la información de las tres tablas manteniendo el contexto, vamos a conectarla en deepnote. Usaremos el csv **<font color='red'>set_total.csv</font>**. **Todas las partes de está consigna seran realizadas en Deepnote**.
#
# **B.** Haremos uso de todos los conocimientos previamente adquiridos. Muchas dudas ya fueron resueltas o tienen objetivos similares.
#
# **C. Contexto**
# 1. Trabajaremos con la última versión de la BBDD relacional **<font color='red'>netflix_oscar.db</font>**. Esta BBDD no está completa ni tiene todas las variables. Puede tener un comportamiento validable. Contiene errores que iremos trabajando durante el desarrollo del curso. No es el objetivo detectar todos los errores, pero sí aprender a reconocerlos y tratarlos adecuadamente.
# 1. La tabla **'content'** tiene información de los contenidos de netflix en general.
# 1. La tabla **'production'** tiene información de los contenidos originales de netflix.
# 1. La tabla **'oscar'** que esta relacionada con los premios a la industria del entretenimiento, especificamente el cine.
# 1. Para referirnos a ciertos usos recurrentes usaremos las siglas siguientes:
# |Referencia|siglas|
# |:-------|:-------:|
# |Bases de datos| BBDD|
# |Hojas de cálculo|HHCC|
# |DataFrame|DF ó df|
#
# **D. Recuerda que:**
# 1. Los ejercicios marcados como **"Desafíos"** son optativos, <u>de entrega no obligatoria</u> pero contribuyen a tu ejercitación como profesional.
# 1. Los enunciados contienen indicaciones mínimas que puedes mejorar. Sé creativo y piensa como si ya fueses un profesional de los datos.
# 1. El material final es un TU PORTAFOLIO piensa en ello para que puedas hacer tu proyecto como te lo pedimos, pero no estaría mal hacer uno paralelo donde puedas hacer más aportes de tu parte.
#
# Recuerda mantener actualizado tu Deepnote.
# <font color='red'>
# # Fecha límite para la entrega: 12/12/2023
# </font>
#
# ### Sigamos adelante. Todo esfuerzo trae recompensa ¡Éxitos!

# %% [markdown]
# # 1.- Códigos de consultas con python
#
# ### 1.- Importar las librerías y métodos para conectar/desconectar la BBDD en deepnote:
#
# * Puedes ver el siguiente video si tienes dudas:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/wIQRoFYXK6E?si=kHI-jY3stPZA4nXX" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" allowfullscreen></iframe>
#
# a) Desarrolar (<font color='blue'>**en la celda de python ubicada abajo llamada**</font> `# des/conexión`) un código en python para la conexión/desconexión de la BBDD **<font color='red'>netflix_oscar.db</font>** .
# Para ello:
#     <b>i.</b> Debe crear un **primer método** para la conexión `get_connetion()` y que retorne la conexión (variable que llamaremos `conn`) y el cursor (variable que llamaremos `cur`).
#     <b>ii.</b> Debe crear un **segundo método** para la desconexión `close_connetion()`. Debe cerrar ambas variables creadas anteriormente de forma adecuada.

# %%
# Des/conexión

import sqlite3 as sq3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import display  # para mostrar display con el estilo DF de Jupiter Notebook

# CONEXION
def get_connetion():
    conn = sq3.connect(f"/work/data/{(data := 'netflix_oscar.db')}")
    cur = conn.cursor()  
    return conn, cur

# DESCONEXION
def close_connetion():
    cur.close()
    conn.close()

# %% [markdown]
# ### 2.- Querys, python y DF de Pandas:
# b) Desarrolar (<font color='blue'>en la celda de python ubicada abajo llamada </font> `# No nulos`) un código en python que obtenga los **no nulos** para la tabla **content** de la BBDD **<font color='red'>netflix_oscar.db</font>**, como lo realizado en las **consigna #2** y **consigna #3**, que genere un DF con estas características:
# <center>
# <table>
#     <tr>
#         <td > </td>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>Nombre columna 1</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></th>
#         <th style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>Nombre columna n</font></th>
#     </tr>
#     <tr>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px">No nulos</td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></td>
#         <td style="border: 1px solid black; padding: 0px 10px 0px 10px"><font color='blue'>...</font></td>
#     </tr>
# </table></center></br>
#
# Para ello:
# * Debe haber ejecutado la celda que hemos llamado `# Des/conexión`
# * Debe llamar al método que le permita conectarse a la base de datos y recuerde que recibe una tupla como respuesta. Maneje cada recurso como le sea conveniente. De esta forma:
#     <b>i.</b> Obtenga el DF con la query que sea necesaria junto al método `.read_sql()` de pandas, puede revisar el crud para recordar como hacerlo.
# * No olvide cerrar la conexión.
#
# <font color='green'>**DESAFIOS**</font>
#
# Desarrollar los siguientes códigos para:
#     <b>I.</b> Completar el DF obtenido en la **consigna #6** (**2.b.i**) con los **nulos, vacios y distintos** para la tabla **content**.
#     <b>II.</b>  El mismo DF obtenido en **2.b.I** pero para las tablas de la BBDD **production** y **oscar**.
# <font color='blue'>Puede desarrollarlos en la misma celda de python llamada </font> `# No nulos`.
# **<font color='blue'>¡Tip puede ser útil el método `.concat()` de pandas!</font>**

# %%
# No nulos
# Para ejecutar esta celda debe haberse ejecutado la primera celda llamada # Des/conexión
conn, cur = get_connetion()

# ESTO NO ES NECESARIO SOLO SIRVE PARA CUALQUIER BBDD SE PUEDE CREAR UN DICCIONARIO DIRECTAMENTE
query_tables = ''' SELECT * 
FROM SQLITE_MASTER
WHERE TYPE  = 'table' AND name NOT LIKE 'sqlite_%';
'''
df_tables = pd.read_sql(query_tables ,conn)
dic_table_column = {table:list(pd.read_sql(f"SELECT name FROM PRAGMA_TABLE_INFO('{table}');",conn).name) for table in df_tables.name} 
index_df = ['NO NULOS','VACIOS','NULOS','DISTINTOS']


# B1
df_cont_notnull = pd.DataFrame(index=[index_df[0]])
key = 'content'
for element in dic_table_column[key]:
        query_notnull_content = f"SELECT COUNT(`{element}`) as '{element}' FROM {key} WHERE `{element}` IS NOT NULL "
        df_notnull_content = pd.read_sql(query_notnull_content ,conn)
        df_notnull_content.index = [index_df[0]]
        df_cont_notnull = pd.concat([df_cont_notnull,df_notnull_content], axis=1)
print('Respuesta 2.b.i', end=' ')
print('Tabla content de no nulos')
display(df_cont_notnull)  # Se acepta print solo que no lo muestra con el estilo DF de Jupiter Notebook
# Out:
# Respuesta 2.b.i Tabla content de no nulos
#           id_content  type  title_content  director  cast  country  \
# NO NULOS        8745  8745           8745      6121  7931     7921
#
#           date_added  release_year  rating  duration  listed_in  description  \
# NO NULOS        8735          8745    8738      8745       8745         8745
#
#           see_content
# NO NULOS         8745

# %%
# PARA RESPUESTA I y II DESAFIOS
df_cont = pd.DataFrame(index=index_df)
df_prod = pd.DataFrame(index=index_df)
df_osc = pd.DataFrame(index=index_df)

for key in dic_table_column:
    for element in dic_table_column[key]:
        query_notnull = f"SELECT COUNT(`{element}`) as '{element}' FROM {key} WHERE `{element}` IS NOT NULL "
        df_notnull = pd.read_sql(query_notnull ,conn)
        df_notnull.index = [index_df[0]]
        
        query_vac = f"SELECT COUNT(`{element}`) as '{element}' FROM {key} WHERE `{element}` LIKE ''"
        df_vac = pd.read_sql(query_vac ,conn)
        df_vac.index = [index_df[1]]
        
        query_null = f"SELECT COUNT(`{dic_table_column[key][0]}`) as '{element}' FROM {key} WHERE `{element}` IS NULL "
        df_null = pd.read_sql(query_null ,conn)
        df_null.index = [index_df[2]]
        
        query_dist = f"SELECT COUNT(DISTINCT `{element}`) as '{element}' FROM {key} "
        df_dist = pd.read_sql(query_dist ,conn)
        df_dist.index = [index_df[3]]
        
        df_joint = pd.concat([df_notnull,df_vac,df_null,df_dist], axis=0)
        if key == 'content':
            df_cont = pd.concat([df_cont,df_joint], axis=1)
        elif key == 'production':
            df_prod = pd.concat([df_prod,df_joint], axis=1)
        else:
            df_osc = pd.concat([df_osc,df_joint], axis=1)

print('Respuesta 2.b.I', end=' ')
print('Tabla de content completa')
display(df_cont)
print('Respuesta 2.b.II',end=' ')
print('Tabla de production completa')
display(df_prod)
print('Respuesta 2.b.II',end=' ')
print('Tabla de oscar completa')
display(df_osc)
close_connetion()
# Out:
# Respuesta 2.b.I Tabla de content completa
#            id_content  type  title_content  director  cast  country  \
# NO NULOS         8745  8745           8745      6121  7931     7921
# VACIOS              0     0              0         0     0        0
# NULOS               0     0              0      2624   814      824
# DISTINTOS        8745     2           8745      4488  7643      744
#
#            date_added  release_year  rating  duration  listed_in  description  \
# NO NULOS         8735          8745    8738      8745       8745         8745
# VACIOS              0             0       0         0          0            0
# NULOS              10             0       7         0          0            0
# DISTINTOS        1759            74      14       220        513         8714
#
#            see_content
# NO NULOS          8745
# VACIOS               0
# NULOS                0
# DISTINTOS            1
# Respuesta 2.b.II Tabla de production completa
#            id_production  id_content  title_production  genre  premiere  \
# NO NULOS             551         551               551    551       551
# VACIOS                 0           0                 0      0         0
# NULOS                  0           0                 0      0         0
# DISTINTOS            551         551               551    110       370
#
#            runtime  imdb_score  language  see_production
# NO NULOS       551         551       551             551
# VACIOS           0           0         0               0
# NULOS            0           0         0               0
# DISTINTOS      118          52        37               1
# Respuesta 2.b.II Tabla de oscar completa
#            id_oscar  id_inf  id_res  id_content  title_oscar  year_ceremony  \
# NO NULOS       2758    2758    2758         444         2758           2758
# VACIOS            0       0       0           0            0              0
# NULOS             0       0       0        2314            0              0
# DISTINTOS      2758     530    2754          78          530             91
#
#            category  name  winner  directed_by  ...  starring  distributed_by  \
# NO NULOS       2758  2758    2758         2753  ...      2628            2652
# VACIOS            0     0       0            0  ...         0               0
# NULOS             0     0       0            5  ...       130             106
# DISTINTOS        93  2164       2          391  ...       490             210
#
#            budget  budget_x_million  box_office  box_office_x_million  imdb  \
# NO NULOS     2497              2476        2526                  2519  2621
# VACIOS          0                 0           0                     0     0
# NULOS         261               282         232                   239   137
# DISTINTOS     246               153         420                   401    38
#
#            metascore  rotten_tomatoes  see_oscar
# NO NULOS        2485             2522       2758
# VACIOS             0                0          0
# NULOS            273              236          0
# DISTINTOS         63               62          1
#
# [4 rows x 21 columns]

# %% [markdown]
# c)  Desarrolar (<font color='blue'>en la celda de python ubicada abajo llamada </font> `# Consultas en DF`) un código en python que permita realizar las siguientes consultas sobre las tabla de la BBDD **<font color='red'>netflix_oscar.db</font>** , como lo realizado en las **consigna #2** y **consigna #3**:
# Para ello:
# *   Debe haber ejecutado la celda que hemos llamado `# Des/conexión`
# *   Debe llamar al método que le permita conectarse a la base de datos y recuerde que recibe una tupla como respuesta. Maneje cada recurso como le sea conveniente.
# *   Obtener el DF de cada una de las tablas de la BBDD con la query apropiada, junto al método `.read_sql()` de pandas, puede revisar el crud para recordar cómo hacerlo.
# *   Finalmente use las estrategías de consulta que sean convenientes para realizar cada una de las siguientes instrucciones (considera  almacenar el DF para cada ejercicio):
#     <b>i.</b>  Listar todos los registros de la tabla, visualizando las columnas type, title_content, country, rating, duration, listed_in.
#     <b>ii.</b>  Generar un listado de todas las películas en las que participe Argentina, mostrando las columnas id_content, type, title_content, director, cast, rating, duration, listed_in.
#     <b>iii.</b>  Presentar un listado con las columnas id_production, title_production, genre, language, imdb_score de los registros de la tabla en las que el imdb_score sea superior a 7.5.
#     <b>iv.</b> Seleccionar los títulos con runtime superior a 90 y lenguaje Francés. Incluir el tipo de contenido. Ordenar los títulos de menor a mayor.
# * No olvide cerrar la conexión.
# <font color='green'>**DESAFIOS**</font>:
# Realizar las siguientes instrucciones (considera  almacenar el DF para cada ejercicio):
#     <b>I.</b>  Todas las filas de la tabla, presentando solo las columnas id_content, title_production, genre, runtime, imdb_Score.
#     <b>II.</b>  Mostrar las columnas id_content, type, title_content, listed_in de los registros en los que el rating sea público general o admitido para todas las edades.
#     <b>III.</b>  Las columnas id_production, title_production, genre de los registros en que duration sea menor o igual a 105 minutos pero que además tenga una duración de al menos 60 minutos.
#     <b>IV.</b>  Mostrar la cantidad  de películas en los idiomas portugués, francés, alemán, italiano y español, ordenados por cantidad, de mayor a menor.
#     <b>V.</b> Sume el Runtime de las películas que tengan como único país de origen United States, India, Japan, Spain y Mexico, discriminando y ordenando por país. Incluya la columna género.
#     <b>VI.</b> Analizar la relación entre Budget y Box Office. Calcular el ratio Budget/Box Office para las peliculas con un puntaje IMDB entre 7 y 9, sin mostrar nulos y no repetidos.
#     <b>VII.</b> Mostrar una lista de las películas originales de netflix ganadoras del oscar (si las hubiera) mostrando las columnas title, category, genre runtime, el imdb_score, la premiere y el año de la ceremonia.
#
# **<font color='blue'>¡Tip en algunos casos pueden ser utiles el método `.str.contains()` de python y los métodos `.merge()`, `.query()`, `.fillna()`, `.groupby()`, `.count()`, `.dropna()`, `.drop()`,`.sum()`, `.sort_index()`, `.reset_index()`, `.drop_duplicates()` y `.sort_values()` o usos de slice simple como otros métodos de filtrados de pandas para obtener los resultados!</font>**
# <font color='blue'>Puede desarrollarlos en la misma celda de python ubicada abajo llamada </font> `# Consultas en DF`.

# %%
# Consultas en DF
# Para ejecutar esta celda debe haberse ejecutado la primera celda llamada # De

conn , cur = get_connetion()

df_content_all = pd.read_sql("SELECT * FROM content", conn)
df_oscar_all = pd.read_sql("SELECT * FROM oscar", conn)
df_prod_all = pd.read_sql("SELECT * FROM production", conn)

df_oscar_all
# Out:
#       id_oscar  id_inf  id_res  id_content title_oscar  year_ceremony  \
# 0            1      26   10359         NaN        1917           2020
# 1            2      26   10368         NaN        1917           2020
# 2            3      26   10395         NaN        1917           2020
# 3            4      26   10399         NaN        1917           2020
# 4            5      26   10412         NaN        1917           2020
# ...        ...     ...     ...         ...         ...            ...
# 2753      2754      77    4311         NaN    Zootopia           1966
# 2754      2755      77    4326         NaN    Zootopia           1966
# 2755      2756      77    4339         NaN    Zootopia           1966
# 2756      2757      77    4349         NaN    Zootopia           1966
# 2757      2758      77    9969         NaN    Zootopia           2017
#
#                                                category  \
# 0                                        CINEMATOGRAPHY
# 1                                             DIRECTING
# 2                                MAKEUP AND HAIRSTYLING
# 3                                MUSIC (Original Score)
# 4                                          BEST PICTURE
# ...                                                 ...
# 2753        MUSIC (Music Score--substantially original)
# 2754                                       BEST PICTURE
# 2755                                              SOUND
# 2756  WRITING (Screenplay--based on material from an...
# 2757                              ANIMATED FEATURE FILM
#
#                                                    name  winner  \
# 0                                         Roger Deakins       1
# 1                                            Sam Mendes       0
# 2        Naomi Donne. Tristan Versluis and Rebecca Cole       0
# 3                                         Thomas Newman       0
# 4     Sam Mendes. Pippa Harris. Jayne-Ann Tenggren a...       0
# ...                                                 ...     ...
# 2753                                      Maurice Jarre       1
# 2754                              Carlo Ponti. Producer       0
# 2755  Metro-Goldwyn-Mayer British Studio Sound Depar...       0
# 2756                                        Robert Bolt       1
# 2757         Byron Howard. Rich Moore and Clark Spencer       1
#
#                          directed_by  ...  \
# 0                         Sam Mendes  ...
# 1                         Sam Mendes  ...
# 2                         Sam Mendes  ...
# 3                         Sam Mendes  ...
# 4                         Sam Mendes  ...
# ...                              ...  ...
# 2753  ['Byron Howard'. 'Rich Moore']  ...
# 2754  ['Byron Howard'. 'Rich Moore']  ...
# 2755  ['Byron Howard'. 'Rich Moore']  ...
# 2756  ['Byron Howard'. 'Rich Moore']  ...
# 2757  ['Byron Howard'. 'Rich Moore']  ...
#
#                                                starring  \
# 0     ['George MacKay'. 'Dean-Charles Chapman'. 'Mar...
# 1     ['George MacKay'. 'Dean-Charles Chapman'. 'Mar...
# 2     ['George MacKay'. 'Dean-Charles Chapman'. 'Mar...
# 3     ['George MacKay'. 'Dean-Charles Chapman'. 'Mar...
# 4     ['George MacKay'. 'Dean-Charles Chapman'. 'Mar...
# ...                                                 ...
# 2753  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...
# 2754  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...
# 2755  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...
# 2756  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...
# 2757  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...
#
#                                          distributed_by        budget  \
# 0     ['Universal Pictures (Worldwide)'. 'Entertainm...   $95 million
# 1     ['Universal Pictures (Worldwide)'. 'Entertainm...   $95 million
# 2     ['Universal Pictures (Worldwide)'. 'Entertainm...   $95 million
# 3     ['Universal Pictures (Worldwide)'. 'Entertainm...   $95 million
# 4     ['Universal Pictures (Worldwide)'. 'Entertainm...   $95 million
# ...                                                 ...           ...
# 2753         ['Walt Disney Studios'. 'Motion Pictures']  $150 million
# 2754         ['Walt Disney Studios'. 'Motion Pictures']  $150 million
# 2755         ['Walt Disney Studios'. 'Motion Pictures']  $150 million
# 2756         ['Walt Disney Studios'. 'Motion Pictures']  $150 million
# 2757         ['Walt Disney Studios'. 'Motion Pictures']  $150 million
#
#      budget_x_million      box_office box_office_x_million  imdb  metascore  \
# 0                95.0  $384.9 million                384.9   8.3       78.0
# 1                95.0  $384.9 million                384.9   8.3       78.0
# 2                95.0  $384.9 million                384.9   8.3       78.0
# 3                95.0  $384.9 million                384.9   8.3       78.0
# 4                95.0  $384.9 million                384.9   8.3       78.0
# ...               ...             ...                  ...   ...        ...
# 2753            150.0  $1.024 billion               1024.0   8.0       78.0
# 2754            150.0  $1.024 billion               1024.0   8.0       78.0
# 2755            150.0  $1.024 billion               1024.0   8.0       78.0
# 2756            150.0  $1.024 billion               1024.0   8.0       78.0
# 2757            150.0  $1.024 billion               1024.0   8.0       78.0
#
#       rotten_tomatoes  see_oscar
# 0                89.0          1
# 1                89.0          1
# 2                89.0          1
# 3                89.0          1
# 4                89.0          1
# ...               ...        ...
# 2753             98.0          1
# 2754             98.0          1
# 2755             98.0          1
# 2756             98.0          1
# 2757             98.0          1
#
# [2758 rows x 21 columns]

# %%
#C1
#Listar todos los registros de la tabla, visualizando las columnas type, title_content, country, rating, duration, listed_in.

df_content_all[["type", "title_content", "country", "rating", "duration", "listed_in"]]
# Out:
#          type          title_content        country rating   duration  \
# 0       Movie   Dick Johnson Is Dead  United States  PG-13     90 min
# 1     TV Show          Blood & Water   South Africa  TV-MA  2 Seasons
# 2     TV Show              Ganglands           None  TV-MA   1 Season
# 3     TV Show  Jailbirds New Orleans           None  TV-MA   1 Season
# 4     TV Show           Kota Factory          India  TV-MA  2 Seasons
# ...       ...                    ...            ...    ...        ...
# 8740    Movie                 Zodiac  United States      R    158 min
# 8741  TV Show            Zombie Dumb           None  TV-Y7  2 Seasons
# 8742    Movie             Zombieland  United States      R     88 min
# 8743    Movie                   Zoom  United States     PG     88 min
# 8744    Movie                 Zubaan          India  TV-14    111 min
#
#                                               listed_in
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8740                     Cult Movies, Dramas, Thrillers
# 8741              Kids TV, Korean TV Shows, TV Comedies
# 8742                            Comedies, Horror Movies
# 8743                 Children & Family Movies, Comedies
# 8744     Dramas, International Movies, Music & Musicals
#
# [8745 rows x 6 columns]

# %%
#C2
#Generar un listado de todas las películas en las que participe Argentina
#mostrando las columnas id_content, type, title_content, director, cast, rating, duration, listed_in.

df_content_all_1 = df_content_all[["id_content","type","title_content","director","cast","country","rating","duration","listed_in"]].fillna("")
df_content_all_1[ df_content_all_1["country"].str.contains("Argentina") ]
# Out:
#       id_content     type                        title_content  \
# 139          141    Movie  El patrón, radiografía de un crimen
# 272          276  TV Show                          The Kingdom
# 299          304    Movie               Esperando la carroza 2
# 301          306    Movie                          Tango Feroz
# 430          435  TV Show                               Okupas
# ...          ...      ...                                  ...
# 7744        7801  TV Show                          Psiconautas
# 8105        8164    Movie                    Temporada de Caza
# 8127        8186    Movie                           The Aerial
# 8214        8274    Movie                     The Desert Bride
# 8646        8709    Movie                     We're No Animals
#
#                           director  \
# 139             Sebastián Schindel
# 272
# 299                Gabriel Condron
# 301                Marcelo Piñeyro
# 430
# ...                            ...
# 7744
# 8105             Natalia Garagiola
# 8127                 Esteban Sapir
# 8214  Cecilia Atán, Valeria Pivato
# 8646             Alejandro Agresti
#
#                                                    cast  \
# 139   Joaquín Furriel, Luis Ziembrowski, Guillermo P...
# 272   Chino Darín, Nancy Dupláa, Joaquín Furriel, Pe...
# 299   Luis Brandoni, Betiana Blum, Roberto Carnaghi,...
# 301   Fernán Mirás, Cecilia Dopazo, Imanol Arias, Hé...
# 430   Rodrigo de la Serna, Diego Alonso, Ariel Stalt...
# ...                                                 ...
# 7744  Guillermo Toledo, Gabriel Goity, Florencia Peñ...
# 8105  Germán Palacios, Lautaro Bettoni, Boy Olmi, Ri...
# 8127  Rafael Ferro, Sol Moreno, Jonathan Sandor, Ale...
# 8214                      Paulina García, Claudio Rissi
# 8646  John Cusack, Paul Hipp, Kevin Morris, Alejandr...
#
#                                                country rating   duration  \
# 139                               Argentina, Venezuela  TV-MA    100 min
# 272                                          Argentina  TV-MA   1 Season
# 299                                          Argentina  TV-MA     88 min
# 301                                   Argentina, Spain  TV-MA    124 min
# 430                                          Argentina  TV-MA   1 Season
# ...                                                ...    ...        ...
# 7744                                         Argentina  TV-MA  2 Seasons
# 8105  Argentina, France, United States, Germany, Qatar  TV-MA    108 min
# 8127                                         Argentina  TV-MA     99 min
# 8214                                  Argentina, Chile  TV-14     78 min
# 8646                          United States, Argentina  TV-MA     94 min
#
#                                               listed_in
# 139             Dramas, International Movies, Thrillers
# 272   Crime TV Shows, International TV Shows, Spanis...
# 299         Comedies, Cult Movies, International Movies
# 301        Classic Movies, Dramas, International Movies
# 430   Classic & Cult TV, Crime TV Shows, Internation...
# ...                                                 ...
# 7744  International TV Shows, Spanish-Language TV Sh...
# 8105                       Dramas, International Movies
# 8127     Dramas, International Movies, Sci-Fi & Fantasy
# 8214                       Dramas, International Movies
# 8646               Comedies, Dramas, Independent Movies
#
# [91 rows x 9 columns]

# %%
#C3
#Presentar un listado con las columnas id_production, title_production, genre, language, imdb_score 
#de los registros de la tabla en las que el imdb_score sea superior a 7.5.

df_prod_all[df_prod_all["imdb_score"] > 7.5][["id_production", "title_production", "genre", "language", "imdb_score"]]
# Out:
#      id_production                             title_production  \
# 33              34                                   Seaspiracy
# 84              86               If Anything Happens I Love You
# 88              90                                         Ludo
# 105            107                   The Trial of the Chicago 7
# 108            110        The Three Deaths of Marisela Escobedo
# 112            114     David Attenborough: A Life on Our Planet
# 128            130                           The Social Dilemma
# 129            131                           My Octopus Teacher
# 160            163                                    Athlete A
# 183            186                                A Secret Love
# 207            210                                   Yeh Ballet
# 216            219                                The Two Popes
# 219            222                               Marriage Story
# 223            226                                 The Irishman
# 229            232                                        Klaus
# 241            244                       Dancing with the Birds
# 244            247                             Tell Me Who I Am
# 315            319                      Springsteen on Broadway
# 339            343                                       Quincy
# 348            352                            The Bleeding Edge
# 415            419                                       Icarus
# 448            452                               The Ivory Game
# 473            478  Winter on Fire: Ukraine's Fight for Freedom
# 476            481                  What Happened, Miss Simone?
# 485            491                               Rising Phoenix
# 489            495           Crip Camp: A Disability Revolution
#
#                                     genre                  language  \
# 33                            Documentary                   English
# 84                      Animation / Short                   English
# 88                  Anthology/Dark comedy                     Hindi
# 105                                 Drama                   English
# 108                           Documentary                   Spanish
# 112                           Documentary                   English
# 128                           Documentary                   English
# 129                           Documentary                   English
# 160                           Documentary                   English
# 183                           Documentary                   English
# 207                                 Drama                     Hindi
# 216                                 Drama                   English
# 219                                 Drama                   English
# 223                           Crime drama                   English
# 229  Animation/Christmas/Comedy/Adventure                   English
# 241                           Documentary                   English
# 244                           Documentary                   English
# 315                          One-man show                   English
# 339                           Documentary                   English
# 348                           Documentary                   English
# 415                           Documentary                   English
# 448                           Documentary                   English
# 473                           Documentary  English/Ukranian/Russian
# 476                           Documentary                   English
# 485                           Documentary                   English
# 489                           Documentary                   English
#
#      imdb_score
# 33          8.2
# 84          7.8
# 88          7.6
# 105         7.8
# 108         8.2
# 112         9.0
# 128         7.6
# 129         8.1
# 160         7.6
# 183         7.9
# 207         7.6
# 216         7.6
# 219         7.9
# 223         7.8
# 229         8.2
# 241         8.3
# 244         7.6
# 315         8.5
# 339         7.6
# 348         7.6
# 415         7.9
# 448         7.9
# 473         8.4
# 476         7.6
# 485         8.1
# 489         7.7

# %%
#C4
#Seleccionar los títulos con runtime superior a 90 y lenguaje Francés.
#Incluir el tipo de contenido. Ordenar los títulos de menor a mayor.

df_prod_all[(df_prod_all["runtime"] >90) & (df_prod_all["language"] == "French")].sort_values("title_production")[["title_production","genre"]]
# Out:
#                              title_production                     genre
# 145                     Anelka: Misunderstood               Documentary
# 536              Bigflo & Oil: Hip Hop Frenzy               Documentary
# 122                       GIMS: On the Record               Documentary
# 519                      I Am Not an Easy Man           Romantic comedy
# 164                               Lost Bullet                  Thriller
# 28                              Madame Claude                     Drama
# 11                                     Oxygen  Science fiction thriller
# 94                                 Rogue City               Crime drama
# 248                               Street Flow                     Drama
# 45      The Misadventures of Hedi and Cokeman                    Comedy
# 343  The Most Assassinated Woman in the World                  Thriller
# 354                          To Each, Her Own           Romantic comedy
# 59                Tony Parker: The Final Shot               Documentary

# %%
#desafios
#1-Todas las filas de la tabla, presentando solo las columnas
#id_content, title_production, genre, runtime, imdb_Score.

df_prod_all[["id_content", "title_production", "genre", "runtime", "imdb_score"]]
# Out:
#      id_content                                title_production  \
# 0             1                            Dick Johnson Is Dead
# 1          1093               Dolly Parton: A MusiCares Tribute
# 2          1071                            Why Did You Kill Me?
# 3           142                                      Extraction
# 4          3988       Antoine Griezmann: The Making of a Legend
# ..          ...                                             ...
# 546        4177    Fyre: The Greatest Party That Never Happened
# 547        5041                            Love per Square Foot
# 548        1873                         The 40-Year-Old Version
# 549        4708                                            Zion
# 550        2258  Mucho Mucho Amor: The Legend of Walter Mercado
#
#                genre  runtime  imdb_score
# 0        Documentary       90         7.5
# 1        Documentary       55         6.5
# 2        Documentary       83         5.6
# 3             Action      117         6.7
# 4        Documentary       60         6.5
# ..               ...      ...         ...
# 546      Documentary       97         7.2
# 547  Romantic comedy      133         7.2
# 548           Comedy      124         7.2
# 549      Documentary       11         7.2
# 550      Documentary       96         7.3
#
# [551 rows x 5 columns]

# %%
#desafio2
#Mostrar las columnas id_content, type, title_content, listed_in de los registros en los que el rating 
#sea público general o admitido para todas las edades.

df_content_all[ (df_content_all["rating"] == "G") | (df_content_all["rating"] == "TV-G")][["id_content", "type", "title_content", "listed_in"]]
# Out:
#       id_content     type                        title_content  \
# 66            67  TV Show        Raja Rasoi Aur Anya Kahaniyan
# 74            76    Movie               You vs. Wild: Out Cold
# 105          107  TV Show                               Bunk'd
# 106          108    Movie                     A Champion Heart
# 107          109  TV Show                            Dive Club
# ...          ...      ...                                  ...
# 8607        8670  TV Show                        V.R. Troopers
# 8640        8703    Movie                          Waterschool
# 8683        8746    Movie  Willy Wonka & the Chocolate Factory
# 8685        8748  TV Show                            Winsanity
# 8724        8787    Movie                         You Can Tutu
#
#                                               listed_in
# 66                   Docuseries, International TV Shows
# 74                             Children & Family Movies
# 105                                Kids TV, TV Comedies
# 106                    Children & Family Movies, Dramas
# 107                   Kids TV, TV Dramas, Teen TV Shows
# ...                                                 ...
# 8607                                            Kids TV
# 8640                                      Documentaries
# 8683  Children & Family Movies, Classic Movies, Come...
# 8685                                         Reality TV
# 8724                           Children & Family Movies
#
# [260 rows x 4 columns]

# %%
#desafio3
#Las columnas id_production, title_production, genre de los registros en que duration sea menor o igual a 105 minutos
#pero que además tenga una duración de al menos 60 minutos.

df_prod_all[ (df_prod_all["runtime"] >= 60 ) & (df_prod_all["runtime"] <= 105)][["id_production", "title_production", "genre"]]
# Out:
#      id_production                                title_production  \
# 0                1                            Dick Johnson Is Dead
# 2                3                            Why Did You Kill Me?
# 4                5       Antoine Griezmann: The Making of a Legend
# 5                6                                      Prime Time
# 6                7                                    Blue Miracle
# ..             ...                                             ...
# 541            552                         El Pepe: A Supreme Life
# 542            553                            Knock Down the House
# 545            556               To All the Boys I've Loved Before
# 546            557    Fyre: The Greatest Party That Never Happened
# 550            562  Mucho Mucho Amor: The Legend of Walter Mercado
#
#                genre
# 0        Documentary
# 2        Documentary
# 4        Documentary
# 5           Thriller
# 6              Drama
# ..               ...
# 541      Documentary
# 542      Documentary
# 545  Romantic comedy
# 546      Documentary
# 550      Documentary
#
# [332 rows x 3 columns]

# %%
#desafio4
#Mostrar la cantidad  de películas en los idiomas portugués, francés, alemán, italiano y español, 
#ordenados por cantidad, de mayor a menor.

df_prod_all.query('language in ["Portuguese","French","German","Italian","Spanish"]')["language"].value_counts()
# Out:
# Spanish       28
# French        20
# Italian       14
# Portuguese    11
# German         5
# Name: language, dtype: int64

# %%
#desafio5. 
#Sume el Runtime de las películas que tengan como único país de origen 
#United States, India, Japan, Spain y Mexico, discriminando y ordenando por país. Incluya la columna género.

df_prod_all_2 = df_prod_all[["id_content","runtime","genre"]]
df_content_2 = df_content_all.query('country in ["United States", "India", "Japan", "Spain", "Mexico"]')[["id_content","country"]]

df_merged = pd.merge(df_prod_all_2, df_content_2, how= "inner", on="id_content")

df2= df_merged.groupby(["country","genre"])["genre","runtime"].sum().sort_values(["country","runtime"], ascending=[True,False])
df2
# Out:
# /tmp/ipykernel_104/1223292801.py:10: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df2= df_merged.groupby(["country","genre"])["genre","runtime"].sum().sort_values(["country","runtime"], ascending=[True,False])
#                                   runtime
# country       genre
# India         Drama                  1791
#               Thriller                602
#               Comedy                  448
#               Romantic comedy         369
#               Comedy-drama            356
# ...                                   ...
# United States Animation                47
#               Animation / Comedy       45
#               Stop Motion              42
#               Animation / Short        28
#               Drama / Short            17
#
# [109 rows x 1 columns]

# %% [markdown]
# d)  Desarrolar el código en python que permita realizar las siguientes instrucciones en el **<font color='red'>set_total.csv</font>** (<font color='blue'>en la celda llamada </font> `# HHCC en DF`), como lo realizado en las **consignas #3 y #4**:
# Para ello:
# *   Debe haber ejecutado la celda que hemos llamado `# Des/conexión`
# *   Obten el DF de cada del csv con el método `.read_csv()` de pandas.
# *   Finalmente use las estrategías de consulta apropiadas para:
#     <b>i</b> Buscar registros duplicados y eliminarlos. <font color='blue'>**Tip puede usar los métodos `.duplicated()`, `.sum()` y `.drop_duplicates()` de pandas.**</font>
#
#     <b>ii</b> Chequear el formato de los datos (numérico en las columnas en que deba haber números, texto en las columnas correspondientes, etc.). <font color='blue'>**Tip puede usar el atributo `.dtypes` y los métodos `.fillna()` y `.astype()` de pandas.**</font>
#
# <font color='green'>**DESAFIOS**</font>:
#
# Realizar las siguientes instrucciones (considera  almacenar el DF para cada ejercicio):
#    <b>I</b> Separar la columna "duration" en dos: en "duration" deben quedar solo los números, mientras que la que quede con los textos deben llamarla "tiempo_temporadas". <font color='blue'>**Tip puede usar el método `.str.split()` de python y los métodos `.index()`, `.reindex()`, `.insert()` y `.pop()` de pandas.**</font>
#
#    <b>II.</b> Construir un DF  que muestre de manera descendente los 15 países que tienen mayor cantidad total de títulos en la plataforma, desglosando por tipo de contenido. <font color='blue'>**Tip puede usar puede usar el método `.str.contains()` de python y los métodos `.count()`, `.unstack()`, `.groupby()`, `.fillna()`, `.head()`, y `.sot_values()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>III.</b> Mostrar las películas clasificadas como **drama** por netflix, que hayan ganado el Oscar entre 2010 y 2020 y que estén en esta plataforma. <font color='blue'>**Tip puede usar el método `.str.contains()` de python y los métodos `.notna()`, `.isin()`, `.count()`, `.groupby()`, `.merge()` y `.reset_index()` de pandas.**</font>
#
#    <b>IV.</b> Construir un DF que muestre el nombre de las películas nominadas, el año de la ceremonia correspondiente, la cantidad de nominaciones y la cantidad de oscar ganados. Agregar una columna que sea el resultado de calcular la relación entre estatuillas ganadas y nominaciones totales. Organizar la tabla con mayor o igual a 10 nominaciones y de mayor a menor por esa de la relación calculada, limitada sólo a las 20 películas de mejor perfomance en los oscar. <font color='blue'>**Tip puede usar los métodos `.sum()`, `.count()`, `.groupby()`, `.reset_index()` y `.sot_values()` de pandas.**</font>
#
#    <b>V</b> Construir un DF que tenga: 1) Una columna con el nombre de los actores/actrices, llamada 'nombres', 2) otra columna llamada 'genero' que indique "Femenino" o "Masculino" en los registros que tienen como categorias ACTOR, ACTOR IN A LEADING ROLE, ACTOR IN A SUPPORTING ROLE, ACTRESS, ACTRESS IN A LEADING ROLE, ACTRESS IN A SUPPORTING ROLE, según corresponda.  3) otra columna que muestre la cantidad de nominaciones al oscar, llamada 'nominaciones' y 4) otra columna que muestre la  la cantidad de victorias al oscar, llamada 'ganados'.  Luego organízalo de mayor a menor por la columna de nominaciones y por la columna de ganados. <font color='blue'>**Tip puede usar el método `.str.contains()` de python y los métodos `.values_counts()`, `.count()`, `.groupby()`, `.merge()`, `.drop_duplicates()`,`.set_index()`, `.concat()`, `.sum()`, `.cumsum()`, `.to_frame()`, `.rename_axis()`, `.reset_index()` y `.sot_values()` de pandas.**</font>
#
# <font color='blue'>Puede desarrollarlos en la misma celda de python ubicada abajo llamada </font> `# HHCC en DF`.

# %%
# HHCC en DF
# Para ejecutar esta celda debe haberse ejecutado la primera celda llamada # Des/conexión

df_set_total = pd.read_csv("/work/data/CSV/set_total.csv")

df_set_total
# Out:
#        id_content     type          title_content  release_year  \
# 0             1.0    Movie   Dick Johnson Is Dead        2020.0
# 1             2.0  TV Show          Blood & Water        2021.0
# 2             3.0  TV Show              Ganglands        2021.0
# 3             4.0  TV Show  Jailbirds New Orleans        2021.0
# 4             5.0  TV Show           Kota Factory        2021.0
# ...           ...      ...                    ...           ...
# 11422         NaN      NaN                    NaN           NaN
# 11423         NaN      NaN                    NaN           NaN
# 11424         NaN      NaN                    NaN           NaN
# 11425         NaN      NaN                    NaN           NaN
# 11426         NaN      NaN                    NaN           NaN
#
#                                                     cast         director  \
# 0                                                    NaN  Kirsten Johnson
# 1      Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...              NaN
# 2      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Julien Leclercq
# 3                                                    NaN              NaN
# 4      Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...              NaN
# ...                                                  ...              ...
# 11422                                                NaN              NaN
# 11423                                                NaN              NaN
# 11424                                                NaN              NaN
# 11425                                                NaN              NaN
# 11426                                                NaN              NaN
#
#              country rating   duration  \
# 0      United States  PG-13     90 min
# 1       South Africa  TV-MA  2 Seasons
# 2                NaN  TV-MA   1 Season
# 3                NaN  TV-MA   1 Season
# 4              India  TV-MA  2 Seasons
# ...              ...    ...        ...
# 11422            NaN    NaN        NaN
# 11423            NaN    NaN        NaN
# 11424            NaN    NaN        NaN
# 11425            NaN    NaN        NaN
# 11426            NaN    NaN        NaN
#
#                                                listed_in  ...  title_oscar  \
# 0                                          Documentaries  ...          NaN
# 1        International TV Shows, TV Dramas, TV Mysteries  ...          NaN
# 2      Crime TV Shows, International TV Shows, TV Act...  ...          NaN
# 3                                 Docuseries, Reality TV  ...          NaN
# 4      International TV Shows, Romantic TV Shows, TV ...  ...          NaN
# ...                                                  ...  ...          ...
# 11422                                                NaN  ...     Zootopia
# 11423                                                NaN  ...     Zootopia
# 11424                                                NaN  ...     Zootopia
# 11425                                                NaN  ...     Zootopia
# 11426                                                NaN  ...     Zootopia
#
#                                                 category  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11422        MUSIC (Music Score--substantially original)
# 11423                                       BEST PICTURE
# 11424                                              SOUND
# 11425  WRITING (Screenplay--based on material from an...
# 11426                              ANIMATED FEATURE FILM
#
#                                                     name year_ceremony winner  \
# 0                                                    NaN           NaN    NaN
# 1                                                    NaN           NaN    NaN
# 2                                                    NaN           NaN    NaN
# 3                                                    NaN           NaN    NaN
# 4                                                    NaN           NaN    NaN
# ...                                                  ...           ...    ...
# 11422                                      Maurice Jarre        1966.0    1.0
# 11423                              Carlo Ponti. Producer        1966.0    0.0
# 11424  Metro-Goldwyn-Mayer British Studio Sound Depar...        1966.0    0.0
# 11425                                        Robert Bolt        1966.0    1.0
# 11426         Byron Howard. Rich Moore and Clark Spencer        2017.0    1.0
#
#                           directed_by  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 11422  ['Byron Howard'. 'Rich Moore']
# 11423  ['Byron Howard'. 'Rich Moore']
# 11424  ['Byron Howard'. 'Rich Moore']
# 11425  ['Byron Howard'. 'Rich Moore']
# 11426  ['Byron Howard'. 'Rich Moore']
#
#                                                 starring  budget_x_million  \
# 0                                                    NaN               NaN
# 1                                                    NaN               NaN
# 2                                                    NaN               NaN
# 3                                                    NaN               NaN
# 4                                                    NaN               NaN
# ...                                                  ...               ...
# 11422  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...             150.0
# 11423  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...             150.0
# 11424  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...             150.0
# 11425  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...             150.0
# 11426  ['Ginnifer Goodwin'. 'Jason Bateman'. 'Idris E...             150.0
#
#       box_office_x_million imdb
# 0                      NaN  NaN
# 1                      NaN  NaN
# 2                      NaN  NaN
# 3                      NaN  NaN
# 4                      NaN  NaN
# ...                    ...  ...
# 11422               1024.0  8.0
# 11423               1024.0  8.0
# 11424               1024.0  8.0
# 11425               1024.0  8.0
# 11426               1024.0  8.0
#
# [11427 rows x 23 columns]

# %%
#D1
#Buscar registros duplicados y eliminarlos.
#Tip puede usar los métodos .duplicated(), .sum() y .drop_duplicates() de pandas.

# %%
df_set_total.duplicated().sum() #dos registros duplicados
# Out:
# 2

# %%
df_set_total.shape
# Out:
# (11427, 23)

# %%
df_set_total.drop_duplicates(inplace=True)
df_set_total.shape
# Out:
# (11425, 23)

# %%
#D2
#Chequear el formato de los datos (numérico en las columnas en que deba haber números, 
#texto en las columnas correspondientes, etc.). Tip puede usar el atributo .dtypes y los métodos .fillna() y .astype() de pandas.

print(df_set_total.dtypes)
# Out:
# id_content              float64
# type                     object
# title_content            object
# release_year            float64
# cast                     object
# director                 object
# country                  object
# rating                   object
# duration                 object
# listed_in                object
# runtime                 float64
# imdb_score              float64
# language                 object
# title_oscar              object
# category                 object
# name                     object
# year_ceremony           float64
# winner                  float64
# directed_by              object
# starring                 object
# budget_x_million        float64
# box_office_x_million    float64
# imdb                    float64
# dtype: object

# %%
df_set_total["id_content"].fillna(0, inplace=True)
df_set_total["id_content"] = df_set_total["id_content"].astype("int64")

# %%
df_set_total["release_year"].fillna(0, inplace=True)
df_set_total["release_year"] = df_set_total["release_year"].astype("int64")

# %%
print(df_set_total.dtypes)
# Out:
# id_content                int64
# type                     object
# title_content            object
# release_year              int64
# cast                     object
# director                 object
# country                  object
# rating                   object
# duration                 object
# listed_in                object
# runtime                 float64
# imdb_score              float64
# language                 object
# title_oscar              object
# category                 object
# name                     object
# year_ceremony           float64
# winner                  float64
# directed_by              object
# starring                 object
# budget_x_million        float64
# box_office_x_million    float64
# imdb                    float64
# dtype: object

# %% [markdown]
# ### 3.- Python, DF de Pandas y Visualización:
# e)  Desarrolar un código en python que permita realizar las siguientes instrucciones en la BBDD **<font color='red'>netflix_oscar.db</font>** (<font color='blue'>en la celda llamada </font> `# Matplotlib`), como en la **consigna #4**:
# Para ello:
# *   Debe haber ejecutado la celda que hemos llamado `# Consultas en DF,` puesto que va a usar cada DF de las tablas de la BBDD, según sea necesario.
# *   Utilice las estrategías de gráficación de matplotlib apropiadas para realizar cada una de las siguientes instrucciones:
#    <b>i.</b> Realizar un gráfico que muestre la relación entre la cantidad de series y películas disponibles en Netflix. <font color='blue'>**Tip puede usar los métodos `.groupby()` y `.count()` de pandas para el tratamiento de los datos.**</font>
#
#    <b>ii.</b> Realizar un gráfico a partir de los países que tienen mayor cantidad total de títulos en la plataforma, desglosando por tipo de contenido, mostrando la información sólo para los primeros 10 países (mostrar el desglose por tipo de contenido), Obvie las cooperaciones entre países. <font color='blue'>**Tip puede usar el método `.str.contains()` de python y los métodos usados en el ejercicio anterior ademas de `.fillna()`, `.head()`, `.drop()`, `.isnull()`, `.unstack()` y `.sort_values()`, de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
# <font color='green'>**DESAFIOS**</font>:
#
# Realizar las siguientes instrucciones, (considera  almacenar el DF para cada ejercicio):
#    <b>I.</b> Diseña una gráfica de barras apiladas que muestre la cantidad total de títulos estrenados por año desglosando por tipos (movie o TV Show) desde el año 2008 hasta la actualidad. <font color='blue'>**Tip puede usar los métodos `.fillna()`, `.head()`, `.drop()`, `.groupby()`, `.sort_index()`, `.isnull()`, `.unstack()` y `.sort_values()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>II.</b> Diseña una gráfica de líneas que muestre la cantidad total de títulos estrenados por año desglosando por tipos (movie o TV Show) desde el año 2008 hasta la actualidad. <font color='blue'>**Tip puede usar los métodos `.fillna()`, `.head()`, `.drop()`, `.groupby()`, `.sort_index()`, `.isnull()`, `.unstack()` y `.sort_values()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
# <font color='blue'>**Tip para los gráficos puede usar los métodos `plt.xticks()`, `ax.set_title()`, `ax.legend()`, `ax.set_ylim()`, `ax.bar_label()` y `plt.subplots()` de matplotlib o sus equivalentes.**</font>
# <font color='blue'>Puede desarrollarlos en la celda de python llamada </font> `# Matplotlib`.

# %%
# Matplotlib
# Para ejecutar esta celda debe haberse ejecutado la tercera celda llamada # Consultas en DF

#E1
#Realizar un gráfico que muestre la relación entre la cantidad de series y películas disponibles en Netflix. Tip puede usar los 
#métodos .groupby() y .count() de pandas para el tratamiento de los datos.

fig, ax = plt.subplots()
c = ["red","green"]
ax.pie(list(df_content_all.groupby("type")["type"].count()), labels=list(df_content_all.groupby("type")["type"].count().index), autopct='%1.2f%%', colors=c)

ax.set_title("Series y películas disponibles en Netflix")
plt.show()

# %%
#E2
#Realizar un gráfico a partir de los países que tienen mayor cantidad total de títulos en la plataforma, 
#desglosando por tipo de contenido, mostrando la información sólo para los primeros 10 países (mostrar el desglose por tipo de contenido), Obvie las cooperaciones entre países. Tip puede usar el método .str.contains() de python y los métodos usados en el ejercicio anterior ademas de .fillna(), .head(), .drop(), .isnull(), .unstack() y .sort_values(), de pandas. Recuerde que para el filtrado en pandas ~ es not, & es and y | es or y encerrar entre paréntesis las operaciones lógicas.

df_content_b = df_content_all[df_content_all["country"].notnull()][["country","type"]]
df_content_b = df_content_b[~df_content_b["country"].str.contains(",")]
df_content_b = df_content_b.groupby(["country" , "type"])["type"].count().unstack().fillna(0)
df_content_b["Total"] = df_content_b["Movie"] + df_content_b["TV Show"]
df_content_b = df_content_b.sort_values("Total", ascending=False).head(10)
df_content_b.drop("Total" ,axis="columns",inplace=True)


n = len(df_content_b.index)
x = np.arange(n)
width = 0.25
value_mul = .5
fig , ax = plt.subplots()

for index_value in list(df_content_b.columns):
    p = ax.bar( x - value_mul*width , df_content_b[index_value] ,width=width , label=index_value)
    value_mul = -0.5
    ax.bar_label(p,padding=5 ,rotation=90)
plt.xticks(x, df_content_b.index , rotation=90)
ax.set_title("Top 10 paises con mayor produccion por tipo")
ax.set_ylim(0,2300)
plt.show()

# %% [markdown]
# f)  Desarrolar un código en python que permita realizar las siguientes instrucciones en la BBDD **<font color='red'>netflix_oscar.db</font>** (<font color='blue'>en la celda de python ubicada abajo llamada </font> `# Seaborn`):
# Para ello:
# *   Debe haber ejecutado la celda que hemos llamado `# Consultas en DF` puesto que va a usar cada DF de las tablas de la BBDD según sea necesario.
# *   Finalmente use las estrategías de gráficación en seaborn que sean convenientes para realizar cada una de las siguientes instrucciones:
#
#    <b>i.</b> Construir un gráfico que muestre de forma descendente el top 20 de directores con más producciones. <font color='blue'>**Tip puede usar los métodos `.count()`, `.cumsum()`, `.head()`, `.to_frame()`, `.isin()`, `.reset_index()`, `.groupby()`, `.sort_values()`, `.isnull()`, `.unstack()` y `.set_index()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>ii.</b> Construir un gráfico que muestre de forma descendente los 20 géneros de Netflix con mayor cantidad de producciones.  <font color='blue'>**Tip puede usar los métodos  `.count()`, `.cumsum()`, `.head()`, `.to_frame()`, `.isin()`, `.reset_index()`, `.groupby()`, `.sort_values()`, `.isnull()`, `.unstack()` y `.set_index()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>iii.</b> Construir un gráfico que muestre de forma descendente todas las clasificaciones por público (rating) desglosando por tipo de contenido. <font color='blue'>**Tip puede usar los métodos  `.count()`, `.copy()`, `.head()`, `.reset_index()`, `.groupby()`, `.sort_values()`, `.isnull()`, `.unstack()` y `.set_index()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>iv.</b> Construir un gráfico que muestre de forma descendente los 15 idiomas de películas con mayor cantidad de títulos, sin contar inglés. <font color='blue'>**Tip puede usar los métodos `.fillna()`, `.count()`, `.cumsum()`, `.head()`, `.reset_index()`, `.groupby()`, `.sort_values()`, `.isnull()`, `.unstack()` y `.set_index()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
# <font color='green'>**DESAFIOS**</font>:
#
# Realizar las siguientes instrucciones, considere para cada ejercicio almacenar el DF que le permita obtener el resultado indicado:
#
#    <b>I.</b> Las que uso para construir el  gráfico 3.e.i (que se propone realizar en Matplotlib). <font color='blue'>**Tip puede usar los métodos `.count()`, y `.T()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>II.</b> Las que uso para construir el  gráfico 3.e.ii (que se propone realizar en Matplotlib). <font color='blue'>**Tip puede usar el método `.str.contains()` de python y los métodos `.fillna()`, `.count()`, `.head()`, `.groupby()`,`.sort_values()`, `.isnull()`, `.unstack()` y `.set_index()`, de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>III.</b> Las que uso para construir el  gráfico 3.e.I (que se propone como desafio en Matplotlib). <font color='blue'>**Tip puede usar el método `.isnull()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
#    <b>IV.</b> Las que uso para construir el  gráfico 3.e.II (que se propone como desafio en Matplotlib).<font color='blue'>**Tip puede usar los métodos `.fillna()`, `.count()`, `.groupby()`,`.set_index()`, `.isnull()`, y `.unstack()` de pandas. Recuerde que para el filtrado en pandas `~ es not`, `& es and` y `| es or` y encerrar entre paréntesis las operaciones lógicas.**</font>
#
# <font color='blue'>**Tip para los gráficos puede usar los métodos `plt.xticks()`, `ax.set_xticklabels()`, `ax.set_xticks()`, `ax.set_yticks()`, `ax.set_title()`, `ax.legend()`, `ax.set_ylim()`, `ax.set_xlim()`, `ax.bar_label()`, `plt.text`, `ax.annotate()`, `plt.xlabel()` y `plt.subplots()` de matplotlib o sus equivalentes para la configuracion del gráfico. Recordemos que se usan los métodos de Seaborn para la gráfica propiamente como `sns.set_style()`.**</font>
# <font color='blue'>Puede desarrollarlos en la misma celda de python ubicada abajo llamada </font> `# Seaborn`.

# %%
# Seaborn
# Para ejecutar esta celda debe haberse ejecutado la tercera celda llamada # Consultas en DF

#F1
#Construir un gráfico que muestre de forma descendente el top 20 de directores con más producciones. Tip puede usar los métodos .count(), .cumsum(), .head(), .to_frame(), .isin(), 
#.reset_index(), .groupby(), .sort_values(), .isnull(), .unstack() y .set_index() de pandas. Recuerde que para el filtrado en pandas ~ es not, & es and y | es or y encerrar entre paréntesis las operaciones lógicas.

df_content_b = df_content_all[df_content_all["director"].notnull()][["type","director"]]

df_content_b = df_content_b.groupby(["director","type"])["type"].count().unstack().fillna(0)

df_content_b["Total"] = df_content_b["Movie"] + df_content_b["TV Show"]

df_content_b = df_content_b.sort_values("Total", ascending=False).head(20)

df_content_c = df_content_all [ df_content_all["director"].isin(df_content_b.index)]



fig, ax = plt.subplots()


sns.countplot(data=df_content_c , x="director", hue="type" , order=df_content_b.index)
ax.set_xticklabels(df_content_b.index , rotation=90)
ax.set_yticks(range(0,20))
ax.legend(loc="best")
ax.set_title("Top 20 directores con mas producciones")

plt.show()

# %%
#F2
#Construir un gráfico que muestre de forma descendente los 20 géneros de Netflix con mayor cantidad de producciones.  Tip puede usar los métodos  .count(), .cumsum(), .head(), .to_frame(), .isin(), 
#.reset_index(), .groupby(), .sort_values(), .isnull(), .unstack() y .set_index() de pandas. Recuerde que para el filtrado en pandas ~ es not, & es and y | es or y encerrar entre paréntesis las operaciones lógicas.


df_content_b = df_content_all.groupby(["listed_in"])["listed_in"].count()
df_content_b = df_content_b.groupby(level=[0]).cumsum().to_frame("cantidad")

df_content_b = df_content_b.sort_values("cantidad", ascending=False).head(20)

df_content_c = df_content_all[ df_content_all["listed_in"].isin(df_content_b.index)]

fig,ax = plt.subplots()

sns.countplot(data=df_content_c , y="listed_in" , order=df_content_b.index)
ax.set_xticks(range(100,370,20))
ax.set_xlim(100,365)
ax.set_title("Top 20 generos de Netflix con mas producciones")

plt.subplot()
# Out:
# <AxesSubplot: title={'center': 'Top 20 generos de Netflix con mas producciones'}, xlabel='count', ylabel='listed_in'>

# %%
#F3
# Construir un gráfico que muestre de forma descendente todas las clasificaciones por público (rating) desglosando por tipo de contenido. Tip puede usar los métodos  .count(), .copy(), .head(), .reset_index(), .groupby(), .sort_values(), .isnull(), .unstack() y .set_index() de pandas. Recuerde que para el filtrado en pandas ~ es not, 
#& es and y | es or y encerrar entre paréntesis las operaciones lógicas.

df_content_b = df_content_all[ df_content_all["rating"].notnull()][["type","rating"]]
df_content_c = df_content_b.copy()
df_content_b = df_content_b.groupby(["rating","type"])["type"].count().unstack().fillna(0)
df_content_b["Total"] = df_content_b["Movie"] + df_content_b["TV Show"]
df_content_b = df_content_b.sort_values("Total", ascending=False).reset_index().head(10)
fig, ax = plt.subplots()
sns.countplot(data=df_content_c , x="rating" , hue="type" , order=df_content_b["rating"])
ax.set_xticklabels(df_content_b.rating, rotation=45)
ax.set_title("Top 10 clasificaciones por publico desglosado por tipo")
plt.show()

# %%
#F4
#Construir un gráfico que muestre de forma descendente los 15 idiomas de películas con mayor cantidad de títulos, sin contar inglés. Tip puede usar los métodos .fillna(), .count(), .cumsum(), .head(), .reset_index(), .groupby(), .sort_values(), .isnull(), .unstack() y .set_index() de pandas. Recuerde que 
#para el filtrado en pandas ~ es not, & es and y | es or y encerrar entre paréntesis las operaciones lógicas.


df_prod_all_iv = df_prod_all[(~df_prod_all['language'].isnull()) & (~df_prod_all['language'].str.contains('English')) & (~df_prod_all['language'].str.contains('/'))][['language']]
df_prod_all_iv = df_prod_all_iv.groupby(['language'])['language'].count().groupby(level =[0]).cumsum().to_frame('cantidad')
df_prod_all_iv = df_prod_all_iv.sort_values('cantidad',ascending=False).reset_index().head(15)
fig, ax = plt.subplots()
sns.barplot(data= df_prod_all_iv, x='language', y='cantidad', order=df_prod_all_iv['language']) 
ax.set_xticklabels(df_prod_all_iv.language, rotation= 90)  
ax.set_yticks(range(0,36,2))
#ax.legend(loc='best')   # plt.legend(loc='best')
ax.set_title('Top 15 idiomas por peliculas con mayor cantidad de titulos')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=328a8476-0120-4336-b323-0f0c5fc3a65f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
